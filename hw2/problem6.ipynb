# %%
# Initial permutation table
initial_permutation_table = [
    57, 49, 41, 33, 25, 17, 9, 1,
    59, 51, 43, 35, 27, 19, 11, 3,
    61, 53, 45, 37, 29, 21, 13, 5,
    63, 55, 47, 39, 31, 23, 15, 7,
    56, 48, 40, 32, 24, 16, 8, 0,
    58, 50, 42, 34, 26, 18, 10, 2,
    60, 52, 44, 36, 28, 20, 12, 4,
    62, 54, 46, 38, 30, 22, 14, 6
]

# Key permutation choice 1 table
key_permutation_choice1_table = [
    56, 48, 40, 32, 24, 16, 8,
    0, 57, 49, 41, 33, 25, 17,
    9, 1, 58, 50, 42, 34, 26,
    18, 10, 2, 59, 51, 43, 35,
    62, 54, 46, 38, 30, 22, 14,
    6, 61, 53, 45, 37, 29, 21,
    13, 5, 60, 52, 44, 36, 28,
    20, 12, 4, 27, 19, 11, 3
]

# Key permutation choice 2 table
key_permutation_choice2_table = [
    13, 16, 10, 23, 0, 4,
    2, 27, 14, 5, 20, 9,
    22, 18, 11, 3, 25, 7,
    15, 6, 26, 19, 12, 1,
    40, 51, 30, 36, 46, 54,
    29, 39, 50, 44, 32, 47,
    43, 48, 38, 55, 33, 52,
    45, 41, 49, 35, 28, 31
]

# Left shift schedule for each round
left_shift_schedule = [
    1, 1, 2, 2, 2, 2, 2, 2,
    1, 2, 2, 2, 2, 2, 2, 1
]

def generate_round_keys(key):
    # Apply permutation choice 1
    permuted_key = [key[index] for index in key_permutation_choice1_table]

    # Split the permuted key into left and right halves
    left_half = permuted_key[:28]
    right_half = permuted_key[28:]

    round_keys = []
    for i in range(16):
        # Perform left circular shift according to the schedule
        left_half = left_half[left_shift_schedule[i]:] + left_half[:left_shift_schedule[i]]
        right_half = right_half[left_shift_schedule[i]:] + right_half[:left_shift_schedule[i]]

        # Merge left and right halves
        combined_key = left_half + right_half

        # Apply permutation choice 2
        round_key = [combined_key[index] for index in key_permutation_choice2_table]

        round_keys.append(round_key)

    return round_keys

# Convert the key "LOVECSND" to binary
key = 'LOVECSND'
key_binary = ''.join(format(ord(char), '08b') for char in key)

# Generate the round keys
round_keys = generate_round_keys(key_binary)

# Print the round keys
for i, key in enumerate(round_keys, 1):
    print(f"Round {i} key: {''.join(key)}")
# Out:
# Round 1 key: 101000001001001011000010101100111110000011011110
# Round 2 key: 101000000001001001010010110000110010111100011111
# Round 3 key: 001001000101101001010000001111110011001110011000
# Round 4 key: 000001100111000101010000011100010101000101100111
# Round 5 key: 000011100100010101010001010001101010100010101110
# Round 6 key: 010011110100000100001001111001000011110111011101
# Round 7 key: 000010111000000110001001001010111001001011111011
# Round 8 key: 000110010000100010001011010101111101110100100011
# Round 9 key: 000110010000101010001000001111001101101100001110
# Round 10 key: 000100000011100010001100110101000101010011110010
# Round 11 key: 000100000010110001000100110011011010101001101001
# Round 12 key: 010000000110110000100100101100101111111001011000
# Round 13 key: 110000001010010100100100001110011001011100110110
# Round 14 key: 110000001000011000100011100111010110110010100010
# Round 15 key: 111000011001001000100010011011000110101001010101
# ...

# %%
# Expansion permutation table
expansion_permutation_table = [
    32, 1, 2, 3, 4, 5,
    4, 5, 6, 7, 8, 9,
    8, 9, 10, 11, 12, 13,
    12, 13, 14, 15, 16, 17,
    16, 17, 18, 19, 20, 21,
    20, 21, 22, 23, 24, 25,
    24, 25, 26, 27, 28, 29,
    28, 29, 30, 31, 32, 1
]

# Permutation table
permutation_table = [
    16, 7, 20, 21, 29, 12, 28, 17,
    1, 15, 23, 26, 5, 18, 31, 10,
    2, 8, 24, 14, 32, 27, 3, 9,
    19, 13, 30, 6, 22, 11, 4, 25
]

# Now the code should work properly without the NameError.


# Define the DES S-boxes
s_boxes = [
    # S1
    [
        [14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7],
        [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8],
        [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0],
        [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13]
    ],
    # S2
    [
        [15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10],
        [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5],
        [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15],
        [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9]
    ],
    # S3
    [
        [10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8],
        [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1],
        [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7],
        [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12]
    ],
    # S4
    [
        [7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15],
        [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9],
        [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4],
        [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14]
    ],
    # S5
    [
        [2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9],
        [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6],
        [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14],
        [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3]
    ],
    # S6
    [
        [12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11],
        [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8],
        [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6],
        [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13]
    ],
    # S7
    [
        [4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1],
        [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6],
        [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2],
        [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12]
    ],
    # S8
    [
        [13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7],
        [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2],
        [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8],
        [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11]
    ]
]

# Initial permutation table
initial_permutation_table = [
    58, 50, 42, 34, 26, 18, 10, 2,
    60, 52, 44, 36, 28, 20, 12, 4,
    62, 54, 46, 38, 30, 22, 14, 6,
    64, 56, 48, 40, 32, 24, 16, 8,
    57, 49, 41, 33, 25, 17, 9, 1,
    59, 51, 43, 35, 27, 19, 11, 3,
    61, 53, 45, 37, 29, 21, 13, 5,
    63, 55, 47, 39, 31, 23, 15, 7
]

# Final permutation table
final_permutation_table = [
    40, 8, 48, 16, 56, 24, 64, 32,
    39, 7, 47, 15, 55, 23, 63, 31,
    38, 6, 46, 14, 54, 22, 62, 30,
    37, 5, 45, 13, 53, 21, 61, 29,
    36, 4, 44, 12, 52, 20, 60, 28,
    35, 3, 43, 11, 51, 19, 59, 27,
    34, 2, 42, 10, 50, 18, 58, 26,
    33, 1, 41, 9, 49, 17, 57, 25
]

def initial_permutation(text):
    return [text[index - 1] for index in initial_permutation_table]

def final_permutation(text):
    return [text[index - 1] for index in final_permutation_table]

def xor(a, b):
    return [x ^ y for x, y in zip(a, b)]

def split_half(text):
    half = len(text) // 2
    return text[:half], text[half:]

def expand_permute(right_half):
    return [right_half[index - 1] for index in expansion_permutation_table]

def s_box_substitution(input_data):
    output = []
    for i in range(8):
        block = input_data[i * 6: (i + 1) * 6]
        row = int(str(block[0]) + str(block[5]), 2)
        column = int(''.join(map(str, block[1:5])), 2)
        value = s_boxes[i][row][column]
        output.extend([int(bit) for bit in format(value, '04b')])
    return output

def permutation(data):
    return [data[index - 1] for index in permutation_table]

def feistel_function(right_half, round_key):
    expanded_half = expand_permute(right_half)
    xored_half = xor(expanded_half, round_key)
    substituted_half = s_box_substitution(xored_half)
    return permutation(substituted_half)

def decrypt_block(block, round_keys):
    left_half, right_half = split_half(block)
    for round_key in reversed(round_keys):
        temp = right_half[:]
        right_half = xor(left_half, feistel_function(right_half, round_key))
        left_half = temp
    return right_half + left_half

def decrypt(ciphertext, round_keys):
    blocks = [ciphertext[i:i+64] for i in range(0, len(ciphertext), 64)]
    plaintext = []
    for block in blocks:
        plaintext += decrypt_block(block, round_keys)
    return plaintext

# Convert ciphertext to binary
ciphertext = "1100101011101101101000100110010101011111101101110011100001110011"
ciphertext_binary = [int(bit) for bit in ciphertext]

# Use the provided round keys for decryption
round_keys = [
    "101000001001001011000010101100111110000011011110",
    "101000000001001001010010110000110010111100011111",
    "001001000101101001010000001111110011001110011000",
    "000001100111000101010000011100010101000101100111",
    "000011100100010101010001010001101010100010101110",
    "010011110100000100001001111001000011110111011101",
    "000010111000000110001001001010111001001011111011",
    "000110010000100010001011010101111101110100100011",
    "000110010000101010001000001111001101101100001110",
    "000100000011100010001100110101000101010011110010",
    "000100000010110001000100110011011010101001101001",
    "010000000110110000100100101100101111111001011000",
    "110000001010010100100100001110011001011100110110",
    "110000001000011000100011100111010110110010100010",
    "111000011001001000100010011011000110101001010101",
    "101000001001001000101010111100101000100010110001"
]

# Convert round keys to binary
round_keys_binary = [[int(bit) for bit in key] for key in round_keys]

# Decrypt the ciphertext
decrypted_text_binary = decrypt(ciphertext_binary, round_keys_binary)

# Convert binary decrypted text to characters
decrypted_text = ''.join([chr(int(''.join(map(str, chunk)), 2)) for chunk in [decrypted_text_binary[i:i+8] for i in range(0, len(decrypted_text_binary), 8)]])

# Print the decrypted text
print("Decrypted Text:", decrypted_text)
# Out:
# Decrypted Text: ¼¨ÝÝS
